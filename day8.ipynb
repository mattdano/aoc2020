# %%
f=open('./day8/input.txt','r')
lines = f.readlines()
f.close()

# %%
lines
# Out:
# ['acc +22\n',
#  'acc +34\n',
#  'jmp +167\n',
#  'acc +46\n',
#  'acc +25\n',
#  'acc -10\n',
#  'acc +11\n',
#  'jmp +540\n',
#  'acc +0\n',
#  'jmp +242\n',
#  'acc +26\n',
#  'acc +46\n',
#  'jmp +242\n',
#  'jmp +287\n',
#  'acc -8\n',
#  'acc +30\n',
#  'acc +3\n',
#  'nop +350\n',
#  'jmp +471\n',
#  'acc +2\n',
#  'acc +0\n',
#  'acc +14\n',
#  'jmp +207\n',
#  'jmp +1\n',
#  'acc -10\n',
#  'acc +12\n',
#  'jmp +281\n',
#  'acc +18\n',
#  'jmp +515\n',
#  'acc -18\n',
#  'acc +33\n',
#  'jmp +379\n',
#  'acc +48\n',
#  'acc +38\n',
#  'jmp +220\n',
#  'acc +44\n',
#  'nop +546\n',
#  'acc +21\n',
#  'jmp +537\n',
#  'acc +33\n',
#  'nop +224\n',
#  'nop +379\n',
#  'jmp +2\n',
#  'jmp -30\n',
#  'jmp +246\n',
#  'acc -14\n',
#  'acc -3\n',
#  'jmp +410\n',
#  'acc +50\n',
#  'nop +323\n',
#  'acc +2\n',
#  'acc +24\n',
#  'jmp +25\n',
#  'jmp +372\n',
#  'acc +29\n',
#  'acc +15\n',
#  'nop +34\n',
#  'jmp +531\n',
#  'acc +48\n',
#  'acc -3\n',
#  'acc -18\n',
# ...

# %% [markdown]
# acc increases or decreases a single global value called the accumulator by the value given in the argument. For example, acc +7 would increase the accumulator by 7. The accumulator starts at 0. After an acc instruction, the instruction immediately below it is executed next.
#
# jmp jumps to a new instruction relative to itself. The next instruction to execute is found using the argument as an offset from the jmp instruction; for example, jmp +2 would skip the next instruction, jmp +1 would continue to the instruction immediately below it, and jmp -20 would cause the instruction 20 lines above to be executed next.
# nop stands for No OPeration - it does nothing. The instruction immediately below it is executed next.

# %%
acc_reg = 0
pos = 0
lineseen = set()

while True:
    rawline = lines[pos]
    opcode,val = rawline.replace('\n','').split(' ')
    val = int(val)
    if opcode == 'acc':
        acc_reg += val
        pos +=1
    if opcode == 'jmp':
        pos += val
    if opcode == 'nop':
        pos +=1
    #print(pos,acc_reg)
    if pos not in lineseen:
        lineseen.add(pos)
    else:
        print(acc_reg)
        break
# Out:
# 1384

# %%
f=open('./day8/input.txt','r')
lines = f.readlines()
f.close()

#lines[592] = 'nop -515\n'

def runcode(lines, linemod):
    f=open('./day8/input.txt','r')
    lines = f.readlines()
    f.close()
    
    if 'jmp' in lines[linemod]:
        lines[linemod] = lines[linemod].replace('jmp','nop')
    elif 'nop' in lines[linemod]:
        lines[linemod] = lines[linemod].replace('nop','jmp')

    
    acc_reg = 0
    pos = 0
    lineseen = set()
    while True:
        rawline = lines[pos]
        opcode,val = rawline.replace('\n','').split(' ')
        val = int(val)
        if opcode == 'acc':
            acc_reg += val
            pos +=1
        if opcode == 'jmp':
            pos += val
        if opcode == 'nop':
            pos +=1
        if pos not in lineseen:
            lineseen.add(pos)
        else:
            #print(acc_reg,pos)
            return None
            break

        if pos == len(lines):
            #print('Fixed:',acc_reg)
            return acc_reg
            break
            
for p in range(0,601):
    ans = runcode(lines,p)
    if ans != None:
        print(ans)
# Out:
# 761
