# %%
f = open('./day3/input.txt')
lines = f.readlines()

# %%
lines
# Out:
# ['.#..#.....#....##..............\n',
#  '...#.#...#...#.#..........#....\n',
#  '#...###...#.#.....#.##.#.#...#.\n',
#  '#.....#.#...##....#...#...#....\n',
#  '##.......##.#.....#........##.#\n',
#  '#..#....#......#..#......#...#.\n',
#  '#..#......#.......#............\n',
#  '##...#.#..#...#........#....##.\n',
#  '#.#.#...#...#..#........#....#.\n',
#  '.......#...........##......#...\n',
#  '##.##.##......#..#............#\n',
#  '..#.###..#..............#......\n',
#  '.##..#.....#......#.#..........\n',
#  '........#.........#....#....###\n',
#  '#..........#........#.#.#......\n',
#  '...##.....#..####.###..#.##....\n',
#  '....#...###............#..#....\n',
#  '...#.#...#.#...#..#.#........##\n',
#  '.....#...#.............#..#....\n',
#  '....#.#.#.##.....##.##....#....\n',
#  '..#....#............#.##.##..#.\n',
#  '.#..#..#................#...###\n',
#  '#..###.#..##..#............#...\n',
#  '.......#.#....#.##.#.##........\n',
#  '##...###.#....#...........###.#\n',
# ...

# %%
rights = [1,3,5,7]
tots = []

for r in rights:
    x = 0
    treecount=0
    for y,line in enumerate(lines):
        if y != 0:
            if line.replace('\n','')[x] == '#':
                treecount +=1
        x+=r
        x=x%len(line.replace('\n',''))
    tots.append(treecount)
    
x = 0
treecount=0
for y,line in enumerate(lines):
    if y != 0 and y%2==0:
        if line.replace('\n','')[x] == '#':
            treecount +=1
    if y%2 == 0:
        x+=1
        x=x%len(line.replace('\n',''))
tots.append(treecount)

# %%
len(lines)
# Out:
# 323

# %%
x=1
for t in tots:
    x*=t
x
# Out:
# 5522401584

# %%
import operator 
operator.mul([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-52334a88dfb9> in <module>
#       1 import operator
# ----> 2 operator.mul([1,2,3,4,5])
#
# TypeError: mul expected 2 arguments, got 1

# %%
84* 289* 89* 71* 36
# Out:
# 5522401584
